# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
training_data=[]
datadir="D:/datasets"
img_size=60


categories=["Cat","Dog"]
def Create_training_data():
    for category in categories:
        path=os.path.join(datadir,category)
        class_num=categories.index(category)
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(img_size,img_size))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
    
Create_training_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-459fb7429bad> in <module>()
#      17                 pass
#      18
# ---> 19 Create_training_data()
#
# <ipython-input-2-459fb7429bad> in Create_training_data()
#       9         path=os.path.join(datadir,category)
#      10         class_num=categories.index(category)
# ---> 11         for img in os.listdir(path):
#      12             try:
#      13                 img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/datasets/Cat'

# %%
len(training_data)

# %%
import random


random.shuffle(training_data)

# %%
features=[]
labels=[]

for feature,label in training_data:
    features.append(feature)
    labels.append(label)

# %%
features=np.array(features).reshape(-1,img_size,img_size,1)

# %%
# import pickle
# filename="image model1.pkl"
# pickle.dump(features,open(filename,"wb"))


# filename="image model2.pkl"
# pickle.dump(labels,open(filename,"wb"))
